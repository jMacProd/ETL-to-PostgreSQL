# %%
import pandas as pd
import numpy as np
import pandas as pd

# %%
# read csv of cities data 
suburbs_path = "../Raw Data/melbourne_suburbs.csv"
postcode_path = "../Raw Data/Aust Postcode Location/Australian_Post_Codes_Lat_Lon.csv"

# %%
suburbnames = pd.read_csv(suburbs_path)
postcode = pd.read_csv(postcode_path)

# %%
#Dataframes
suburbnamesDF = pd.DataFrame(suburbnames)
suburbnamesDF['suburb'] = suburbnamesDF['suburb'].str.lower()
suburbnamesDF
# Out:
#                  suburb
# 0            abbotsford
# 1            aberfeldie
# 2          airport west
# 3             albanvale
# 4           albert park
# ..                  ...
# 317        williamstown
# 318  williamstown north
# 319             windsor
# 320           yallambie
# 321          yarraville
#
# [322 rows x 1 columns]

# %%
postcodeDF = pd.DataFrame(postcode)
postcodeDF['suburb'] = postcodeDF['suburb'].str.lower()
postcodeDF
# Out:
#        postcode                          suburb state  \
# 0           200  australian national university   ACT
# 1           221                          barton   ACT
# 2           800                          darwin    NT
# 3           801                          darwin    NT
# 4           804                           parap    NT
# ...         ...                             ...   ...
# 16075      9010                        brisbane   QLD
# 16076      9013                        brisbane   QLD
# 16077      9015                        brisbane   QLD
# 16078      9020                        brisbane   QLD
# 16079         0                             NaN   NaN
#
#                                 dc  \
# 0      AUSTRALIAN NATIONAL UNI LPO
# 1                              NaN
# 2           DARWIN DELIVERY CENTRE
# 3           DARWIN DELIVERY CENTRE
# 4                            PARAP
# ...                            ...
# 16075           CITY DC - BRISBANE
# 16076           CITY DC - BRISBANE
# 16077           CITY DC - BRISBANE
# 16078           CITY DC - BRISBANE
# 16079                          NaN
#
#                                                 type        lat         lon
# 0      Post Office Boxes                             -35.277272  149.117136
# 1      LVR                                           -35.201372  149.095065
# 2      Delivery Area                                 -12.801028  130.955789
# 3      Post Office Boxes                             -12.801028  130.955789
# 4      Post Office Boxes                             -12.432181  130.843310
# ...                                              ...        ...         ...
# 16075  LVR                                           -27.603479  152.823141
# 16076  LVR                                           -27.603479  152.823141
# 16077  LVR                                           -27.603479  152.823141
# 16078  LVR                                           -27.603479  152.823141
# 16079                                            NaN        NaN         NaN
#
# [16080 rows x 7 columns]

# %%
suburbpostcodemerge = pd.merge(suburbnamesDF, postcodeDF, on= "suburb",  how ="left")
suburbpostcodemerge
# Out:
#            suburb  postcode state                          dc  \
# 0      abbotsford    2046.0   NSW    LIDCOMBE DELIVERY CENTRE
# 1      abbotsford    3067.0   VIC                  FITZROY DC
# 2      abbotsford    4670.0   QLD                BUNDABERG DC
# 3      aberfeldie    3040.0   VIC             MOONEE PONDS DC
# 4    airport west    3042.0   VIC                  NIDDRIE DC
# ..            ...       ...   ...                         ...
# 480       windsor    3181.0   VIC                 RICHMOND DC
# 481       windsor    4030.0   QLD                 STAFFORD DC
# 482       windsor    5501.0    SA               TWO WELLS LPO
# 483     yallambie    3085.0   VIC  HEIDELBERG WEST DEL CENTRE
# 484    yarraville    3013.0   VIC           WEST FOOTSCRAY DC
#
#                                               type        lat         lon
# 0    Delivery Area                                 -33.852469  151.129453
# 1    Delivery Area                                 -37.801781  144.998752
# 2    Delivery Area                                 -24.843687  152.024909
# 3    Delivery Area                                 -37.756690  144.896259
# 4    Delivery Area                                 -37.711698  144.887037
# ..                                             ...        ...         ...
# 480  Delivery Area                                 -37.856159  144.992200
# 481  Delivery Area                                 -27.435277  153.031507
# 482  Delivery Area                                 -34.421671  138.330791
# 483  Delivery Area                                 -37.727482  145.102309
# 484  Delivery Area                                 -37.816178  144.889774
#
# [485 rows x 7 columns]

# %%
# Get names of indexes for which column state doesn not equal VIC
indexNames = suburbpostcodemerge[ suburbpostcodemerge['state'] != "VIC" ].index

# %%
# Delete these row indexes from dataFrame
suburbpostcodemerge.drop(indexNames , inplace=True)

# %%
suburbpostcodemerge
# Out:
#                  suburb  postcode state                          dc  \
# 1            abbotsford    3067.0   VIC                  FITZROY DC
# 3            aberfeldie    3040.0   VIC             MOONEE PONDS DC
# 4          airport west    3042.0   VIC                  NIDDRIE DC
# 5             albanvale    3021.0   VIC                ST ALBANS DC
# 6           albert park    3206.0   VIC          SOUTH MELBOURNE DC
# ..                  ...       ...   ...                         ...
# 475        williamstown    3016.0   VIC                  NEWPORT DC
# 478  williamstown north    3016.0   VIC                  NEWPORT DC
# 480             windsor    3181.0   VIC                 RICHMOND DC
# 483           yallambie    3085.0   VIC  HEIDELBERG WEST DEL CENTRE
# 484          yarraville    3013.0   VIC           WEST FOOTSCRAY DC
#
#                                               type        lat         lon
# 1    Delivery Area                                 -37.801781  144.998752
# 3    Delivery Area                                 -37.756690  144.896259
# 4    Delivery Area                                 -37.711698  144.887037
# 5    Delivery Area                                 -37.745934  144.770027
# 6    Delivery Area                                 -37.840705  144.955710
# ..                                             ...        ...         ...
# 475  Delivery Area                                 -37.856902  144.897698
# 478  Delivery Area                                 -37.857681  144.887041
# 480  Delivery Area                                 -37.856159  144.992200
# 483  Delivery Area                                 -37.727482  145.102309
# 484  Delivery Area                                 -37.816178  144.889774
#
# [354 rows x 7 columns]

# %%
suburbpostcodemerge['postcode'].dtypes
# Out:
# dtype('float64')

# %%
suburbpostcodemerge.postcode = suburbpostcodemerge.postcode.astype(int)

# %%
suburbpostcodemerge['postcode'].dtypes
# Out:
# dtype('int64')

# %%
suburbpostcodemerge
# Out:
#                  suburb  postcode state                          dc  \
# 1            abbotsford      3067   VIC                  FITZROY DC
# 3            aberfeldie      3040   VIC             MOONEE PONDS DC
# 4          airport west      3042   VIC                  NIDDRIE DC
# 5             albanvale      3021   VIC                ST ALBANS DC
# 6           albert park      3206   VIC          SOUTH MELBOURNE DC
# ..                  ...       ...   ...                         ...
# 475        williamstown      3016   VIC                  NEWPORT DC
# 478  williamstown north      3016   VIC                  NEWPORT DC
# 480             windsor      3181   VIC                 RICHMOND DC
# 483           yallambie      3085   VIC  HEIDELBERG WEST DEL CENTRE
# 484          yarraville      3013   VIC           WEST FOOTSCRAY DC
#
#                                               type        lat         lon
# 1    Delivery Area                                 -37.801781  144.998752
# 3    Delivery Area                                 -37.756690  144.896259
# 4    Delivery Area                                 -37.711698  144.887037
# 5    Delivery Area                                 -37.745934  144.770027
# 6    Delivery Area                                 -37.840705  144.955710
# ..                                             ...        ...         ...
# 475  Delivery Area                                 -37.856902  144.897698
# 478  Delivery Area                                 -37.857681  144.887041
# 480  Delivery Area                                 -37.856159  144.992200
# 483  Delivery Area                                 -37.727482  145.102309
# 484  Delivery Area                                 -37.816178  144.889774
#
# [354 rows x 7 columns]

# %%
suburbpostcodemerge.to_csv('../Raw Data/melbourbe_suburbs_postcode.csv', index=False)
