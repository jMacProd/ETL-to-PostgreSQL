# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read in csv for crime data
filepathway = "../03 TRANSFORMATION 2 - Clean up/suburb_vs_crime.csv"

# %%
#Create dataframe for crime data
crime_DF_final = pd.read_csv(filepathway)
crime_DF_final
# Out:
#           lga_name  postcode        suburb crime_id  \
# 0          Banyule      3079       ivanhoe      A20
# 1          Banyule      3079       ivanhoe      A50
# 2          Banyule      3079       ivanhoe      A70
# 3          Banyule      3079       ivanhoe      A80
# 4          Banyule      3079       ivanhoe      B10
# ...            ...       ...           ...      ...
# 7512  Yarra Ranges      3796  mount evelyn      D30
# 7513  Yarra Ranges      3796  mount evelyn      E10
# 7514  Yarra Ranges      3796  mount evelyn      E20
# 7515  Yarra Ranges      3796  mount evelyn      F90
# 7516  Yarra Ranges      3796  mount evelyn    Other
#
#                                            crime_name  average_incident
# 0                        Assault and related offences         43.600000
# 1                                             Robbery          3.000000
# 2      Stalking, harassment and threatening behaviour          8.100000
# 3     Dangerous and negligent acts endangering people          3.333333
# 4                                               Arson          3.400000
# ...                                               ...               ...
# 7512                         Public nuisance offences          1.833333
# 7513                               Justice procedures          4.250000
# 7514                               Breaches of orders         21.800000
# 7515                           Miscellaneous offences          4.333333
# 7516                        crimes against the person         10.300000
#
# [7517 rows x 6 columns]

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM 
    #of the crime rate for each suburb

# This method produces everything in a single groupby function
crimeGroup = crime_DF_final.groupby(["suburb"])
crimeagg = crimeGroup["average_incident"].agg(["mean", "median", "var", "std", "sem"])
crimeaggsort = crimeagg.sort_values(by="mean", ascending=False) 

crimerate_summary = crimeaggsort.rename(columns={
    "mean":"Mean crime rates per quarter",
    "median":"Median crime rates per quarter",
    "var":"Variance crime rates per quarter",
    "std":"Standard Deviation crime rates per quarter",
    "sem":"SEM  crime rates per quarter"
})

crimerate_summary
# Out:
#             Mean crime rates per quarter  Median crime rates per quarter  \
# suburb
# melbourne                     463.457190                       29.800000
# dandenong                     244.041667                       91.650000
# frankston                     240.721098                       67.800000
# preston                       174.957350                       45.300000
# reservoir                     146.031566                       46.072222
# ...                                  ...                             ...
# selby                           2.134649                        1.250000
# sassafras                       2.043959                        1.464286
# the patch                       1.929340                        1.666667
# clematis                        1.591667                        1.600000
# sherbrooke                      1.505159                        1.083333
#
#             Variance crime rates per quarter  \
# suburb
# melbourne                       1.953620e+06
# dandenong                       1.444471e+05
# frankston                       1.590321e+05
# preston                         1.583782e+05
# reservoir                       7.323417e+04
# ...                                      ...
# selby                           3.143644e+00
# sassafras                       2.936829e+00
# the patch                       8.967705e-01
# clematis                        3.431250e-01
# sherbrooke                      5.791649e-01
#
#             Standard Deviation crime rates per quarter  \
# suburb
# melbourne                                  1397.719599
# dandenong                                   380.061932
# frankston                                   398.788351
# preston                                     397.967596
# reservoir                                   270.618119
# ...                                                ...
# selby                                         1.773032
# sassafras                                     1.713718
# the patch                                     0.946980
# clematis                                      0.585769
# sherbrooke                                    0.761029
#
#             SEM  crime rates per quarter
# suburb
# melbourne                     170.758627
# dandenong                      77.579817
# frankston                      81.402331
# preston                        82.981980
# reservoir                      57.695977
# ...                                  ...
# selby                           0.406762
# sassafras                       0.403927
# the patch                       0.236745
# clematis                        0.162463
# sherbrooke                      0.219690
#
# [313 rows x 5 columns]

# %%
 #The summary table above and trial visualisation shows there is extreme outliers - need to smooth the data
#https://www.geeksforgeeks.org/detect-and-remove-the-outliers-using-python/
#Detection
    # IQR 
    
    
Q1 = np.percentile(crime_DF_final['average_incident'], 25, interpolation = 'midpoint')

Q3 = np.percentile(crime_DF_final['average_incident'], 75, interpolation = 'midpoint')

IQR = Q3 - Q1

print("Old Shape: ", crime_DF_final.shape)


# Upper bound 
upper = np.where(crime_DF_final['average_incident'] >= (Q3+1.5*IQR)) 
# Lower bound 
lower = np.where(crime_DF_final['average_incident'] <= (Q1-1.5*IQR))

#''' Removing the Outliers '''
crime_DF_final.drop(upper[0], inplace = True) 
crime_DF_final.drop(lower[0], inplace = True) 
  
print("New Shape: ", crime_DF_final.shape)
# Out:
# Old Shape:  (7517, 6)
# New Shape:  (6486, 6)

# %%
# Generate a NEW summary statistics table of mean, median, variance, standard deviation, and SEM 
    #of the crime rate for each suburb

# This method produces everything in a single groupby function
crimeGroupsmooth = crime_DF_final.groupby(["suburb"])
crimeaggsmooth = crimeGroupsmooth["average_incident"].agg(["mean", "median", "var", "std", "sem"])
crimeaggsmoothsort = crimeaggsmooth.sort_values(by="mean", ascending=False) 

crimerate_summary = crimeaggsmoothsort.rename(columns={
    "mean":"Mean crime rates per quarter",
    "var":"Variance crime rates per quarter",
    "std":"Standard Deviation crime rates per quarter",
    "sem":"SEM  crime rates per quarter"
})

crimerate_summary
# Out:
#                   Mean crime rates per quarter     median  \
# suburb
# reservoir                            22.441204  25.300000
# preston                              21.787075  20.800000
# cranbourne                           20.197778  19.400000
# hoppers crossing                     20.088235  19.600000
# craigieburn                          19.342222  15.000000
# ...                                        ...        ...
# selby                                 2.134649   1.250000
# sassafras                             2.043959   1.464286
# the patch                             1.929340   1.666667
# clematis                              1.591667   1.600000
# sherbrooke                            1.505159   1.083333
#
#                   Variance crime rates per quarter  \
# suburb
# reservoir                               291.070575
# preston                                 316.699573
# cranbourne                              284.358169
# hoppers crossing                        255.889436
# craigieburn                             249.879122
# ...                                            ...
# selby                                     3.143644
# sassafras                                 2.936829
# the patch                                 0.896771
# clematis                                  0.343125
# sherbrooke                                0.579165
#
#                   Standard Deviation crime rates per quarter  \
# suburb
# reservoir                                          17.060791
# preston                                            17.796055
# cranbourne                                         16.862923
# hoppers crossing                                   15.996545
# craigieburn                                        15.807565
# ...                                                      ...
# selby                                               1.773032
# sassafras                                           1.713718
# the patch                                           0.946980
# clematis                                            0.585769
# sherbrooke                                          0.761029
#
#                   SEM  crime rates per quarter
# suburb
# reservoir                             4.925026
# preston                               4.756196
# cranbourne                            4.353988
# hoppers crossing                      3.879732
# craigieburn                           4.081496
# ...                                        ...
# selby                                 0.406762
# sassafras                             0.403927
# the patch                             0.236745
# clematis                              0.162463
# sherbrooke                            0.219690
#
# [313 rows x 5 columns]

# %%
#Top ten summary stats by mean
crimerate_summary_topten = crimerate_summary.head(10)

crimerate_summary_topten.to_csv('crimerate_summary_topten.csv', index=True)
crimerate_summary_topten
# Out:
#                   Mean crime rates per quarter     median  \
# suburb
# reservoir                            22.441204  25.300000
# preston                              21.787075  20.800000
# cranbourne                           20.197778  19.400000
# hoppers crossing                     20.088235  19.600000
# craigieburn                          19.342222  15.000000
# broadmeadows                         18.680741  14.100000
# berwick                              17.957143  15.966667
# footscray                            17.612755  10.850000
# springvale                           17.418132  16.900000
# narre warren                         17.209804  15.000000
#
#                   Variance crime rates per quarter  \
# suburb
# reservoir                               291.070575
# preston                                 316.699573
# cranbourne                              284.358169
# hoppers crossing                        255.889436
# craigieburn                             249.879122
# broadmeadows                            300.702548
# berwick                                 173.736996
# footscray                               252.735355
# springvale                              148.646774
# narre warren                            264.197467
#
#                   Standard Deviation crime rates per quarter  \
# suburb
# reservoir                                          17.060791
# preston                                            17.796055
# cranbourne                                         16.862923
# hoppers crossing                                   15.996545
# craigieburn                                        15.807565
# broadmeadows                                       17.340777
# berwick                                            13.180933
# footscray                                          15.897652
# springvale                                         12.192078
# narre warren                                       16.254152
#
#                   SEM  crime rates per quarter
# suburb
# reservoir                             4.925026
# preston                               4.756196
# cranbourne                            4.353988
# hoppers crossing                      3.879732
# craigieburn                           4.081496
# broadmeadows                          4.477369
# berwick                               3.522753
# footscray                             4.248826
# springvale                            3.381474
# narre warren                          3.942211

# %%
#Bottom ten summary stats by mean
crimeaggsortbottom = crimeagg.sort_values(by="mean", ascending=True) 

crimerate_summary = crimeaggsortbottom.rename(columns={
    "mean":"Mean crime rates per quarter",
    "var":"Variance crime rates per quarter",
    "std":"Standard Deviation crime rates per quarter",
    "sem":"SEM  crime rates per quarter"
})

crimerate_summary_bottomten = crimerate_summary.head(10)

crimerate_summary_bottomten.to_csv('crimerate_summary_bottomten.csv', index=True)
crimerate_summary_bottomten
# Out:
#                     Mean crime rates per quarter    median  \
# suburb
# sherbrooke                              1.505159  1.083333
# clematis                                1.591667  1.600000
# the patch                               1.929340  1.666667
# sassafras                               2.043959  1.464286
# selby                                   2.134649  1.250000
# north warrandyte                        2.182639  1.416667
# junction village                        2.284226  1.775000
# belgrave heights                        2.393170  1.333333
# strathmore heights                      2.396508  1.333333
# langwarrin south                        2.463095  1.708333
#
#                     Variance crime rates per quarter  \
# suburb
# sherbrooke                                  0.579165
# clematis                                    0.343125
# the patch                                   0.896771
# sassafras                                   2.936829
# selby                                       3.143644
# north warrandyte                            4.473152
# junction village                            4.056224
# belgrave heights                            4.865610
# strathmore heights                          9.404859
# langwarrin south                            4.832550
#
#                     Standard Deviation crime rates per quarter  \
# suburb
# sherbrooke                                            0.761029
# clematis                                              0.585769
# the patch                                             0.946980
# sassafras                                             1.713718
# selby                                                 1.773032
# north warrandyte                                      2.114983
# junction village                                      2.014007
# belgrave heights                                      2.205813
# strathmore heights                                    3.066734
# langwarrin south                                      2.198306
#
#                     SEM  crime rates per quarter
# suburb
# sherbrooke                              0.219690
# clematis                                0.162463
# the patch                               0.236745
# sassafras                               0.403927
# selby                                   0.406762
# north warrandyte                        0.528746
# junction village                        0.503502
# belgrave heights                        0.506048
# strathmore heights                      0.685743
# langwarrin south                        0.518146

# %%
#histogram -Average crimes rates within a quarter
fig, ax = plt.subplots(figsize = (12,6))

ax.hist(crime_DF_final["average_incident"], bins=12)
ax.set_title("Histogram: Average crime rates within a quarter")
ax.set_xlabel("Crime rate")
ax.set_ylabel("Frequency")

plt.show()
plt.savefig('Hist_avg_crimerate.png')

# %%
#bar plot - TYPES oF CRIME
#Find the mean of the incidents recorded
Crimetypesgroup = crime_DF_final.groupby(['crime_name'])
crimetypesaverage = Crimetypesgroup['average_incident'].mean()
crimetypesavgDF = pd.DataFrame(crimetypesaverage)

crimetypesavgDFsort = crimetypesavgDF.sort_values(by="average_incident", ascending=False) 

crimetypesavgDFsort
# Out:
#                                                  average_incident
# crime_name
# Burglary/Break and enter                                19.993858
# Property damage                                         19.142172
# Assault and related offences                            17.884954
# Theft                                                   17.226436
# Breaches of orders                                      15.096084
# Deception                                               14.633073
# Miscellaneous offences                                  14.014313
# Drug use and possession                                 11.439842
# Disorderly and offensive conduct                         9.577472
# crimes against the person                                9.573634
# Weapons and explosives offences                          9.471395
# Stalking, harassment and threatening behaviour           8.474064
# Justice procedures                                       7.289899
# Robbery                                                  5.297319
# Drug dealing and trafficking                             4.969979
# Dangerous and negligent acts endangering people          4.931592
# Arson                                                    4.350847
# Public nuisance offences                                 3.020883
# Cultivate or manufacture drugs                           2.439805
# Other government regulatory offences                     1.785021
# Transport regulation offences                            1.687058
# Public security offences                                 1.222208
# Other drug offences                                      1.196065
# Bribery                                                  1.131250
# Regulatory driving offences                              1.117816

# %%
plt.bar(crimetypesavgDFsort.index, crimetypesavgDFsort["average_incident"])
plt.xticks(rotation=90)

plt.title("Bar: Average crime rates by type within a quarter")
plt.xlabel('Crime Type')  
plt.ylabel('Average Rate')
#plt.savefig('../Visualizations/Lat_vs_Temp.png')


plt.show()
plt.savefig('Bar_avg_crimerate_type.png')
