# %% [markdown]
# # Check called API data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load csv made from api call

# %%
file_url = '01_Outputs/melb_suburbs_types.csv'
df = pd.read_csv(file_url)
df
# Out:
#                  suburb  postcode state                          dc  \
# 0            abbotsford      3067   VIC                  FITZROY DC
# 1            aberfeldie      3040   VIC             MOONEE PONDS DC
# 2          airport west      3042   VIC                  NIDDRIE DC
# 3             albanvale      3021   VIC                ST ALBANS DC
# 4           albert park      3206   VIC          SOUTH MELBOURNE DC
# ..                  ...       ...   ...                         ...
# 311        williamstown      3016   VIC                  NEWPORT DC
# 312  williamstown north      3016   VIC                  NEWPORT DC
# 313             windsor      3181   VIC                 RICHMOND DC
# 314           yallambie      3085   VIC  HEIDELBERG WEST DEL CENTRE
# 315          yarraville      3013   VIC           WEST FOOTSCRAY DC
#
#               type        lat         lon  No liquor_store  No police  No park
# ...

# %% [markdown]
# # Plot suburbs a place counts

# %%
fig, ax = plt.subplots(figsize=(40,20))
labels = df["suburb"]
xvalue1 = df["No liquor_store"]
xvalue2 = df["No police"]
xvalue3 = df["No park"]
ax.bar(labels, xvalue3)
ax.bar(labels, xvalue1)
ax.bar(labels, xvalue2)
plt.xticks(rotation=90)

fig.savefig('01_Outputs/suburb_api_counts.jpg')

plt.show()

# %% [markdown]
# Graph shows API results used as counts caps out at 20.
#
# https://developers.google.com/maps/documentation/places/web-service/search
#
# "Accessing Additional Results
#
# By default, each Nearby Search or Text Search returns up to 20 establishment results per query"

# %% [markdown]
# ### Suburbs that have no search terms found in google places api

# %%
zero_df = df.loc[(df["No liquor_store"] == 0) & (df["No police"] == 0) & (df["No park"] == 0)]
zero_df
# Out:
#                suburb  postcode state                      dc           type  \
# 29          bellfield      3381   VIC                 STAWELL  Delivery Area
# 99      diamond creek      3089   VIC        DIAMOND CREEK DC  Delivery Area
# 153          hillside      3875   VIC              BAIRNSDALE  Delivery Area
# 183  langwarrin south      3911   VIC  BAXTER DELIVERY ANNEXE  Delivery Area
#
#            lat         lon  No liquor_store  No police  No park
# 29  -37.228577  142.480053              0.0        0.0      0.0
# 99  -37.642629  145.217595              0.0        0.0      0.0
# 153 -37.830936  147.470591              0.0        0.0      0.0
# 183 -38.198507  145.182526              0.0        0.0      0.0

# %% [markdown]
# Only 4 suburbs have no results for any search term. This can be a result of suburb size, population and many other factors
