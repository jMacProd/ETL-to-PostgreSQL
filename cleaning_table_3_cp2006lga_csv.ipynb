# %%
import pandas as pd
import numpy as np

# %%
postcode_lga_df = pd.read_csv('Raw Data/LGA(councils)_postcode(POA)/CP2006LGA_2006POA.csv')

# %%
postcode_lga_df
# Out:
#       LGA_2006_Code                LGA_2006_Name  POA_2006_Code  \
# 0             10050                   Albury (C)           2640
# 1             10050                   Albury (C)           2641
# 2             10050                   Albury (C)           2642
# 3             10110        Armidale Dumaresq (A)           2350
# 4             10150                 Ashfield (A)           2045
# ...             ...                          ...            ...
# 3281          89399           Unincorporated ACT           2914
# 3282          99399  Unincorp. Other Territories           2540
# 3283          99399  Unincorp. Other Territories           6798
# 3284          99399  Unincorp. Other Territories           6799
# 3285          99399  Unincorp. Other Territories           9999
#
#       POA_2006_Name     Ratio     Percent
# 0              2640  1.000000  100.000000
# 1              2641  1.000000  100.000000
# 2              2642  0.139574   13.957400
# ...

# %%
postcode_lga_df.columns = ['local_gov_area_code','local_gov_name','post_code','post_code_2','ratio','percent']
postcode_lga_df
# Out:
#       local_gov_area_code               local_gov_name  post_code  \
# 0                   10050                   Albury (C)       2640
# 1                   10050                   Albury (C)       2641
# 2                   10050                   Albury (C)       2642
# 3                   10110        Armidale Dumaresq (A)       2350
# 4                   10150                 Ashfield (A)       2045
# ...                   ...                          ...        ...
# 3281                89399           Unincorporated ACT       2914
# 3282                99399  Unincorp. Other Territories       2540
# 3283                99399  Unincorp. Other Territories       6798
# 3284                99399  Unincorp. Other Territories       6799
# 3285                99399  Unincorp. Other Territories       9999
#
#       post_code_2     ratio     percent
# 0            2640  1.000000  100.000000
# 1            2641  1.000000  100.000000
# 2            2642  0.139574   13.957400
# ...

# %%
postcode_lga_df = postcode_lga_df[['local_gov_name','post_code']].copy()
postcode_lga_df
#df2.loc[df2["post_code"] == 3150,:]
# Out:
#                    local_gov_name  post_code
# 0                      Albury (C)       2640
# 1                      Albury (C)       2641
# 2                      Albury (C)       2642
# 3           Armidale Dumaresq (A)       2350
# 4                    Ashfield (A)       2045
# ...                           ...        ...
# 3281           Unincorporated ACT       2914
# 3282  Unincorp. Other Territories       2540
# 3283  Unincorp. Other Territories       6798
# 3284  Unincorp. Other Territories       6799
# 3285  Unincorp. Other Territories       9999
#
# [3286 rows x 2 columns]

# %%
np.dtype(postcode_lga_df["post_code"][0])
# Out:
# dtype('int64')

# %%
crime_df = pd.read_excel('Raw Data/Crime rate/table3_criminal_incidents_offence_lga_postcode_suburb_oct2010 _sept2020.xlsx')

# %%
crime_df.head()
# Out:
#    Year Year ending Local Government Area  Postcode Suburb/Town Name  \
# 0  2020   September                Alpine      3691         Dederang
# 1  2020   September                Alpine      3691       Glen Creek
# 2  2020   September                Alpine      3691       Glen Creek
# 3  2020   September                Alpine      3691       Gundowring
# 4  2020   September                Alpine      3691       Gundowring
#
#                     Offence Division          Offence Subdivision  \
# 0  B Property and deception offences                    B40 Theft
# 1                    C Drug offences  C30 Drug use and possession
# 2                   F Other offences   F90 Miscellaneous offences
# 3  B Property and deception offences                    B40 Theft
# 4      E Justice procedures offences       E10 Justice procedures
#
#                Offence Subgroup  Incidents Recorded
# 0       B41 Motor vehicle theft                   1
# ...
